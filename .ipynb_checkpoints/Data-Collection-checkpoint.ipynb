# %%
import requests
import json
import ast
import pandas as pd
import os

# %%
autorization = {"accept": "application/json", "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5ZDI2ZmZiNWNiZmM0OWNiNzdmNmFkYjFlMmE5MzRkMSIsInN1YiI6IjYyMGE5N2Q4MjZkYWMxMDBiODc1ZmU0OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZKQXGcGF5FkrHUW0jqcNjHXTCYS56Rlh4JToRmp2A7Q"}

# %% [markdown]
# # Functions Code

# %%
def extractor(category,data_kind,detail):
    if data_kind == "ids":
        url = f"https://api.themoviedb.org/3/discover/{category}?page={detail}"
    else:
        url = f"https://api.themoviedb.org/3/{category}/{detail}?api_key=8277ae593821f15114e4b063f6ff057b&append_to_response=credits"
    
    response = requests.get(url, headers=autorization)
    jsonic = response.text
    json_dump = json.dumps(jsonic)
    another_dump = json.loads(json_dump)
    data = json.loads(another_dump)
    if data_kind == 'ids':
        id_lst = []
        for i in data['results']:
            id_lst.append(i['id'])
        total_pages = data['total_pages']
        total_results = data['total_results']
        return {'pages':total_pages,'ids':id_lst,"results":total_results}
    else:
        if category == 'movie':
            return {"category":"movies","data":data}
        elif category == 'tv':
            return {"category":"tv","data":data}
    page_execution+=1

# %%
def info(record):
    category = record['category']
    its_data = record['data']
    for its in its_data:
        temp_dict[its].append(its_data[its])

# %%
def emptyDict(record):
    key_names = record['data'].keys()
    its_data = record['data']
    for its in key_names:
        temp_dict[its] = []
        temp_dict[its].append(its_data[its])

# %%
def extract_new_record(identity):
    movie_data = extractor(extractFor,"",identity)
    if len(temp_dict) != 0:
        info(movie_data)
    else:
        emptyDict(movie_data)

# %% [markdown]
# # Extract Key Value Vals

# %%
def extractValues(value,name):
    value_type = type(value)
    if value_type == list:
        #print("list")
        e_val = []
        for i in value:
            e_val.append(i[name])
        return ", ".join(e_val)
    if value_type == dict:
        #print("dict")
        return value[name]
    else:
        #print("other")
        return value

# %%
def extractSubValues(value,category):
    for i in value:
        if i == category:
            sub_data = value[i]
            return extractValues(sub_data,'name')

# %%
def extractSubValuesCondition(value,category,job):
    for i in value:
        if i == category:
            for j in value[i]:
                if j['job'] == job:
                    return extractValues(j,'name')

# %%
temp_dict = {}

# %%
def addData(data):
    if len(temp_dict) != 0:
        info(data)
    else:
        emptyDict(data)

# %%
def adding_new_data(page_nos,ext_name,response):
    count = 0
    for num in range(page_nos):
        record = extractor(ext_name,"ids",num+1)
        #print(f"{num} => {record}")
        if count <= response - 1:
            for data in record['ids']:
                if count <= response - 1:
                    print(f"{count+1} => {data}")
                    movie_data = extractor(ext_name,"",data)
                    addData(movie_data)
                    count+=1
        else:
            break

# %%
def updated_new_data(df,page_nos,ext_name,response):
    count = 0
    #print(df)
    for num in range(page_nos):
        record = extractor(ext_name,"ids",num+1)
        #print(f"{record}")
        if count <= response - 1:
            for data in record['ids']:
                found = df[(df['id'] == data)]
                if(found.shape[0] > 0):
                    print(f"yes ({data})")
                    pass
                else:
                    if count <= response - 1:
                        print(f"{count+1} => No ({data})")
                        movie_data = extractor(ext_name,"",data)
                        addData(movie_data)
                        count+=1
                    else:
                        break
        else:
            break

# %%
def temporaryRec(maxRec='',extractFor=''):
    pages = extractor(extractFor,"ids",1)['pages']
    total_res = extractor(extractFor,"ids",1)['results']
    try:
        movie_df = pd.read_csv('./data/movies.csv')
        getting_length = movie_df.shape[0]
        if maxRec == '':
            #maxRec = total_res - getting_length
            maxRec = 5000
        updated_new_data(movie_df,pages,extractFor,maxRec)
    except:
        print("Darame Not Found")
        if maxRec == '':
            maxRec = total_res
            adding_new_data(pages,extractFor,maxRec)
        else:
            adding_new_data(pages,extractFor,maxRec)

# %%
temporaryRec(1000,"movie")
# Out:
# Darame Not Found
# 1 => 447365
# 2 => 385687
# 3 => 455476
# 4 => 667538
# 5 => 254128
# 6 => 678512
# 7 => 1070802
# 8 => 1130818
# 9 => 445651
# 10 => 569094
# 11 => 603692
# 12 => 406563
# 13 => 502356
# 14 => 47964
# 15 => 976573
# 16 => 1103825
# 17 => 697843
# 18 => 614479
# 19 => 346698
# 20 => 664767
# 21 => 423108
# 22 => 396263
# 23 => 575264
# 24 => 841755
# 25 => 1036561
# 26 => 447277
# 27 => 1010581
# 28 => 298618
# 29 => 76600
# 30 => 994143
# 31 => 714669
# 32 => 917007
# 33 => 536437
# 34 => 713704
# 35 => 890771
# 36 => 204553
# 37 => 986070
# 38 => 758323
# 39 => 543504
# 40 => 882569
# 41 => 1129956
# 42 => 640146
# 43 => 840326
# 44 => 993867
# 45 => 961323
# 46 => 335977
# 47 => 315162
# 48 => 677179
# 49 => 594767
# 50 => 22620

# %%
temp_dict
# Out:
# {'adult': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'backdrop_path': ['/5YZbUmjbMa3ClvSW1Wj3D6XGolb.jpg',
#   '/4XM8DUTQb3lhLemJC51Jx4a2EuA.jpg',
#   '/oqP1qEZccq5AD9TVTIaO6IGUj7o.jpg',
#   '/woJbg7ZqidhpvqFGGMRhWQNoxwa.jpg',
#   '/zcySy6dnSmyqiichtDgO7AEeZoq.jpg',
#   '/84cS9oEm33jD05T0p39TbwADY8.jpg',
#   '/euO884625eFLfKLoc0MtFs5QiOS.jpg',
#   '/qe0oK0A5ovrlgH39Ga13dxxw9MU.jpg',
#   '/rPBeEi1tU8IhQ9rbdnlLU0d0NR.jpg',
#   '/4HodYYKEIsGOdinkGi2Ucz6X9i0.jpg',
#   '/h8gHn0OzBoaefsYseUByqsmEDMY.jpg',
#   '/PwI3EfasE9fVuXsmMu9ffJh0Re.jpg',
#   '/9n2tJBplPbgR2ca05hS5CKXwP2c.jpg',
#   '/mV1HOCbUqx7nfFPwledYsvMYHrw.jpg',
#   '/cSYLX73WskxCgvpN3MtRkYUSj1T.jpg',
#   '/zxnfMi4qW0bdAtcwCogrR9dRrqd.jpg',
#   '/wRxLAw4l17LqiFcPLkobriPTZAw.jpg',
#   '/aO6hDsqTIAtQFUBoPWklmPFsSTW.jpg',
#   '/nHf61UzkfFno5X1ofIhugCPus2R.jpg',
#   '/vw3zNfzvnVNF7nIjpiEgcdznfeC.jpg',
#   '/qi6Edc1OPcyENecGtz8TF0DUr9e.jpg',
#   '/ddAQBXqxog1sgjfDf8qeMTuEbMO.jpg',
#   '/bYJv39whWTAOWO0mv7oUija8GgM.jpg',
#   '/dssCw0mUmD4EriUmkwB3PnsGu4q.jpg',
#   '/xDEVdWduhRdNS4PzA6wif6FjUQb.jpg',
#   '/fCw8CVgII6W7ALbIh0SgXax3Hsj.jpg',
#   '/lntyt4OVDbcxA1l7LtwITbrD3FI.jpg',
#   '/yF1eOkaYvwiORauRCPWznV9xVvi.jpg',
#   '/8rpDcsfLJypbO6vREc0547VKqEv.jpg',
#   '/8Y0RxH5cXiKV8C9Wyj6JkW9VYaG.jpg',
#   '/37LyKFPr7ksoXMea7MIWFa8Llaj.jpg',
#   '/lQzSMhkAl90iXPirjnLbRHkxApC.jpg',
#   '/8FhKnPpql374qyyHAkZDld93IUw.jpg',
#   '/7bWxAsNPv9CXHOhZbJVlj2KxgfP.jpg',
#   '/9t0tJXcOdWwwxmGTk112HGDaT0Q.jpg',
#   '/fsBo2qolgyW02IhR9IqeFByhM4b.jpg',
#   '/osnvZffaZymubHiBkOsIFd8Y3Re.jpg',
#   '/hiHGRbyTcbZoLsYYkO4QiCLYe34.jpg',
#   '/70DKGgzTwyC7fr3FGM6JSHGqmPm.jpg',
#   '/eTvN54pd83TrSEOz6wbsXEJktCV.jpg',
#   '/u6bGwwMgQhcqQJKHASwN4PEcYyj.jpg',
#   '/m8JTwHFwX7I7JY5fPe4SjqejWag.jpg',
#   '/o9bbojtrrpl0yriiTmzC3Lp3OhA.jpg',
#   '/ulaj7IhW72EK0cGSnMpP0UixTTC.jpg',
#   '/4QpKxH614YFIsmiIBVUbsnG2H8w.jpg',
#   '/35z8hWuzfFUZQaYog8E9LsXW3iI.jpg',
#   '/jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg',
#   '/8QsVX5C82mT7bB5sVsjsLcerWQK.jpg',
#   '/zRQITMLvVi8z2Xz12Bi6wvbZE82.jpg',
#   '/tgH4bAlDJjhxies1AuKZkNP5SSI.jpg'],
#  'belongs_to_collection': [{'id': 284433,
#    'name': 'Guardians of the Galaxy Collection',
#    'poster_path': '/iL8mukexAqEg0xK783rG561tdd8.jpg',
#    'backdrop_path': '/jdyyjulTBU8YUYAUvQFj6U1g2Pj.jpg'},
#   {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/yvr1Ziehgps1VJyug8nnezTJRJW.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   None,
#   {'id': 939352,
#    'name': 'Transformers: Rise of the Beasts Collection',
#    'poster_path': None,
#    'backdrop_path': None},
#   None,
#   None,
#   None,
#   None,
#   None,
#   {'id': 573436,
#    'name': 'Spider-Man: Spider-Verse Collection',
#    'poster_path': '/eD4bGQNfmqExIAzKdvX5gDHhI2.jpg',
#    'backdrop_path': '/14F6gMaRjzgsN6EEpiwH87R1I00.jpg'},
#   {'id': 404609,
#    'name': 'John Wick Collection',
#    'poster_path': '/xUidyvYFsbbuExifLkslpcd8SMc.jpg',
#    'backdrop_path': '/fSwYa5q2xRkBoOOjueLpkLf3N1m.jpg'},
#   {'id': 228446,
#    'name': 'Insidious Collection',
#    'poster_path': '/w1213HKk1XKSwHiBgjkWghn9biC.jpg',
#    'backdrop_path': '/5FrPZHgbbmTIq0oxpwSGqu5HyXC.jpg'},
#   None,
#   {'id': 1570,
#    'name': 'Die Hard Collection',
#    'poster_path': '/fn3aXwADNC0nmJ51GYnkrOseVgB.jpg',
#    'backdrop_path': '/5kHVblr87FUScuab1PVSsK692IL.jpg'},
#   None,
#   None,
#   {'id': 735127,
#    'name': 'Extraction Collection',
#    'poster_path': '/r3UzhVpENoCb8n2bZPClWdhsSH8.jpg',
#    'backdrop_path': '/gxBbFVb2SUWtHTJQXjwAtEPTWcA.jpg'},
#   {'id': 228446,
#    'name': 'Insidious Collection',
#    'poster_path': '/w1213HKk1XKSwHiBgjkWghn9biC.jpg',
#    'backdrop_path': '/5FrPZHgbbmTIq0oxpwSGqu5HyXC.jpg'},
#   None,
#   {'id': 848690,
#    'name': 'Mortal Kombat Legends Collection',
#    'poster_path': '/gwji7KRUN3tUQRiFDbOCkzZxXP8.jpg',
#    'backdrop_path': '/cANyFSat8bE44dK9vOVk5jbEsov.jpg'},
#   {'id': 313086,
#    'name': 'The Conjuring Collection',
#    'poster_path': '/z5VKhNSQKQyxm0co68HAkCqHnmX.jpg',
#    'backdrop_path': '/kHZaX0vuhZdbuq0WKU3BpA9WIQ0.jpg'},
#   {'id': 99321,
#    'name': 'Gantz Collection',
#    'poster_path': '/4nybjgZf153YzEvRVyaGXckz7rl.jpg',
#    'backdrop_path': '/m5NYwsLPsAxxdrm67RxII19yENV.jpg'},
#   {'id': 87359,
#    'name': 'Mission: Impossible Collection',
#    'poster_path': '/geEjCGfdmRAA1skBPwojcdvnZ8A.jpg',
#    'backdrop_path': '/jYl0UuJFcmhymv9ZNO14lPLDY1Z.jpg'},
#   {'id': 848690,
#    'name': 'Mortal Kombat Legends Collection',
#    'poster_path': '/gwji7KRUN3tUQRiFDbOCkzZxXP8.jpg',
#    'backdrop_path': '/cANyFSat8bE44dK9vOVk5jbEsov.jpg'},
#   None,
#   None,
#   None,
#   None,
#   {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/gC3tW9a45RGOzzSh6wv91pFnmFr.jpg',
#    'backdrop_path': '/iaEsDbQPE45hQU2EGiNjXD2KWuF.jpg'},
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   {'id': 986072,
#    'name': 'Becky Collection',
#    'poster_path': '/mFJB9lbBzyw2VlRmsmyY3tDyyvq.jpg',
#    'backdrop_path': '/AlD1IP0ThUfoQnDnoDOAudqVyP5.jpg'},
#   None,
#   None,
#   None,
#   None,
#   {'id': 422834,
#    'name': 'Ant-Man Collection',
#    'poster_path': '/qxMs5TU6zOTQ7cbmBZ6xGvHUDa2.jpg',
#    'backdrop_path': '/2KjtWUBiksmN8LsUouaZnxocu5N.jpg'},
#   None,
#   None,
#   None,
#   {'id': 84,
#    'name': 'Indiana Jones Collection',
#    'poster_path': '/lpxDrACKJhbbGOlwVMNz5YCj6SI.jpg',
#    'backdrop_path': '/6kh59mZizZsttZPR0HAdXk6Ve2n.jpg'},
#   {'id': 94602,
#    'name': 'Puss in Boots Collection',
#    'poster_path': '/anHwj9IupRoRZZ98WTBvHpTiE6A.jpg',
#    'backdrop_path': '/feU1DWV5zMWxXUHJyAIk3dHRQ9c.jpg'},
#   {'id': 553717,
#    'name': 'Creed Collection',
#    'poster_path': '/c5iwhO9Oqx5zusx0VeaoyxP50Wr.jpg',
#    'backdrop_path': '/qIRBVovMpYsEi5LUXN4WULYXLpC.jpg'},
#   {'id': 724848,
#    'name': 'Shazam! Collection',
#    'poster_path': '/7eskWm1guoeWJ0tLV7aXkyvIzcI.jpg',
#    'backdrop_path': '/vNFGaJCPRnGkDJhzZcEZ3llmcvi.jpg'},
#   {'id': 633815,
#    'name': 'Scooby-Doo! The Mystery Begins Collection',
#    'poster_path': '/jMFjeqbyNObFnJVyXUhTGoSinni.jpg',
#    'backdrop_path': '/sp9lRbTgkqY3zooedCMfpR0X2yG.jpg'}],
#  'budget': [250000000,
#   340000000,
#   60000000,
#   200000000,
#   110000000,
#   0,
#   0,
#   0,
#   34000000,
#   100000000,
#   90000000,
#   10000000,
#   100000000,
#   92000000,
#   200000000,
#   0,
#   0,
#   16000000,
#   100000000,
#   0,
#   39000000,
#   0,
#   290000000,
#   0,
#   0,
#   250000000,
#   0,
#   190000000,
#   460000000,
#   15000,
#   0,
#   0,
#   70000000,
#   15000000,
#   0,
#   0,
#   0,
#   18000000,
#   0,
#   55000000,
#   0,
#   200000000,
#   6200000,
#   5000,
#   0,
#   295000000,
#   90000000,
#   75000000,
#   125000000,
#   0],
#  'genres': [[{'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 14, 'name': 'Fantasy'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}],
#   [{'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 28, 'name': 'Action'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 80, 'name': 'Crime'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 18, 'name': 'Drama'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 80, 'name': 'Crime'}],
#   [{'id': 27, 'name': 'Horror'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 35, 'name': 'Comedy'}],
#   [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   [{'id': 16, 'name': 'Animation'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   [{'id': 27, 'name': 'Horror'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 35, 'name': 'Comedy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'}],
#   [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'}],
#   [{'id': 27, 'name': 'Horror'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 16, 'name': 'Animation'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   [{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}],
#   [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'}],
#   [{'id': 27, 'name': 'Horror'}],
#   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}],
#   [{'id': 27, 'name': 'Horror'}],
#   [{'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}],
#   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}],
#   [{'id': 12, 'name': 'Adventure'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 9648, 'name': 'Mystery'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 10752, 'name': 'War'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 80, 'name': 'Crime'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'}],
#   [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   [{'id': 28, 'name': 'Action'}, {'id': 10752, 'name': 'War'}],
#   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}],
#   [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'}],
#   [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'}],
#   [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'}],
#   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}],
#   [{'id': 35, 'name': 'Comedy'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 14, 'name': 'Fantasy'}],
#   [{'id': 9648, 'name': 'Mystery'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 14, 'name': 'Fantasy'}]],
#  'homepage': ['https://www.marvel.com/movies/guardians-of-the-galaxy-volume-3',
#   'https://fastxmovie.com',
#   'https://kotzmovie.com',
#   'https://www.transformersmovie.com',
#   'http://www.sanandreasmovie.com/',
#   'https://www.soundoffreedommovie.com/',
#   '',
#   '',
#   'https://www.20thcenturystudios.com/movies/the-darkest-minds',
#   'https://www.acrossthespiderverse.movie',
#   'https://johnwick.movie',
#   'http://www.insidiousmovie.com',
#   'https://www.thesupermariobros.movie',
#   'http://www.diehardmovie.com/',
#   'https://movies.disney.com/elemental',
#   '',
#   'https://www.netflix.com/title/81098494',
#   'https://www.insidious.movie',
#   'https://www.barbie-themovie.com',
#   'https://www.warnerbros.com/movies/mortal-kombat-legends-scorpions-revenge',
#   'http://www.theconjuringmovie.net',
#   'http://gantzo.jp/',
#   'https://www.missionimpossible.com',
#   'https://www.warnerbros.com/movies/mortal-kombat-legends-battle-realms',
#   '',
#   'https://movies.disney.com/the-little-mermaid-2023',
#   '',
#   'https://www.dc.com/theflash',
#   'https://www.avatar.com/movies/avatar-the-way-of-water',
#   'https://www.skinamarink.com',
#   'https://www.netflix.com/title/81664196',
#   '',
#   'https://www.ketchupentertainment.com/hypnotic',
#   'https://www.evildeadrisemovie.com',
#   'https://theavenue.film/movies/the-black-demon',
#   '',
#   '',
#   'https://www.thepopes-exorcist.movie',
#   '',
#   'https://www.mgmstudios.com/the-covenant',
#   'https://www.netflix.com/title/81516052',
#   'https://www.marvel.com/movies/ant-man-and-the-wasp-quantumania',
#   '',
#   '',
#   'https://www.netflix.com/title/81444554',
#   'https://movies.disney.com/indiana-jones-and-the-dial-of-destiny',
#   'https://www.dreamworks.com/movies/puss-in-boots-the-last-wish',
#   'https://www.mgmstudios.com/creed-iii',
#   '',
#   ''],
#  'id': [447365,
#   385687,
#   455476,
#   667538,
#   254128,
#   678512,
#   1070802,
#   1130818,
#   445651,
#   569094,
#   603692,
#   406563,
#   502356,
#   47964,
#   976573,
#   1103825,
#   697843,
#   614479,
#   346698,
#   664767,
#   423108,
#   396263,
#   575264,
#   841755,
#   1036561,
#   447277,
#   1010581,
#   298618,
#   76600,
#   994143,
#   714669,
#   917007,
#   536437,
#   713704,
#   890771,
#   204553,
#   986070,
#   758323,
#   543504,
#   882569,
#   1129956,
#   640146,
#   840326,
#   993867,
#   961323,
#   335977,
#   315162,
#   677179,
#   594767,
#   22620],
#  'imdb_id': ['tt6791350',
#   'tt5433140',
#   'tt6528290',
#   'tt5090568',
#   'tt2126355',
#   'tt7599146',
#   'tt21391242',
#   'tt16970906',
#   'tt4073790',
#   'tt9362722',
#   'tt10366206',
#   'tt5726086',
#   'tt6718170',
#   'tt1606378',
#   'tt15789038',
#   'tt12519802',
#   'tt12263384',
#   'tt13405778',
#   'tt1517268',
#   'tt9580138',
#   'tt7069210',
#   'tt5923962',
#   'tt9603212',
#   'tt14901058',
#   'tt19879786',
#   'tt5971474',
#   'tt21909764',
#   'tt0439572',
#   'tt1630029',
#   'tt21307994',
#   'tt12547822',
#   'tt4896168',
#   'tt8080204',
#   'tt13345606',
#   'tt10279472',
#   'tt2969656',
#   'tt20916568',
#   'tt13375076',
#   'tt10283270',
#   'tt4873118',
#   'tt27728519',
#   'tt10954600',
#   'tt14846026',
#   'tt20835552',
#   'tt19500164',
#   'tt1462764',
#   'tt3915174',
#   'tt11145118',
#   'tt10151854',
#   'tt1258157'],
#  'original_language': ['en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'ja',
#   'en',
#   'en',
#   'en',
#   'en',
#   'es',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'ko',
#   'en',
#   'en',
#   'cn',
#   'en',
#   'en',
#   'en',
#   'fi',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en',
#   'en'],
#  'original_title': ['Guardians of the Galaxy Vol. 3',
#   'Fast X',
#   'Knights of the Zodiac',
#   'Transformers: Rise of the Beasts',
#   'San Andreas',
#   'Sound of Freedom',
#   'Confidential Informant',
#   'Sheroes',
#   'The Darkest Minds',
#   'Spider-Man: Across the Spider-Verse',
#   'John Wick: Chapter 4',
#   'Insidious: The Last Key',
#   'The Super Mario Bros. Movie',
#   'A Good Day to Die Hard',
#   'Elemental',
#   'War of the Worlds: The Attack',
#   'Extraction 2',
#   'Insidious: The Red Door',
#   'Barbie',
#   "Mortal Kombat Legends: Scorpion's Revenge",
#   'The Conjuring: The Devil Made Me Do It',
#   'GANTZ:O',
#   'Mission: Impossible - Dead Reckoning Part One',
#   'Mortal Kombat Legends: Battle of the Realms',
#   'Shadow Master',
#   'The Little Mermaid',
#   'Culpa mía',
#   'The Flash',
#   'Avatar: The Way of Water',
#   'Skinamarink',
#   'Run Rabbit Run',
#   'Bed Rest',
#   'Hypnotic',
#   'Evil Dead Rise',
#   'The Black Demon',
#   '감시자들',
#   'The Wrath of Becky',
#   "The Pope's Exorcist",
#   '神探大战',
#   "Guy Ritchie's The Covenant",
#   'iNumber Number: Jozi Gold',
#   'Ant-Man and the Wasp: Quantumania',
#   'Sisu',
#   'Eradication',
#   'Nimona',
#   'Indiana Jones and the Dial of Destiny',
#   'Puss in Boots: The Last Wish',
#   'Creed III',
#   'Shazam! Fury of the Gods',
#   'Scooby-Doo! The Mystery Begins'],
#  'overview': ['Peter Quill, still reeling from the loss of Gamora, must rally his team around him to defend the universe along with protecting one of their own. A mission that, if not completed successfully, could quite possibly lead to the end of the Guardians as we know them.',
#   "Over many missions and against impossible odds, Dom Toretto and his family have outsmarted, out-nerved and outdriven every foe in their path. Now, they confront the most lethal opponent they've ever faced: A terrifying threat emerging from the shadows of the past who's fueled by blood revenge, and who is determined to shatter this family and destroy everything—and everyone—that Dom loves, forever.",
#   'When a headstrong street orphan, Seiya, in search of his abducted sister unwittingly taps into hidden powers, he discovers he might be the only person alive who can protect a reincarnated goddess, sent to watch over humanity. Can he let his past go and embrace his destiny to become a Knight of the Zodiac?',
#   'When a new threat capable of destroying the entire planet emerges, Optimus Prime and the Autobots must team up with a powerful faction known as the Maximals. With the fate of humanity hanging in the balance, humans Noah and Elena will do whatever it takes to help the Transformers as they engage in the ultimate battle to save Earth.',
#   'In the aftermath of a massive earthquake in California, a rescue-chopper pilot makes a dangerous journey across the state in order to rescue his estranged daughter.',
#   'The story of Tim Ballard, a former US government agent, who quits his job in order to devote his life to rescuing children from global sex traffickers.',
#   'During a crack epidemic two narcotics agents hunting for a cop killer. Hoping for leads, Moran and Thorton pay off a junkie informant. To provide for his wife and son, Moran involves the stool pigeon in a deadly scheme. This causes the partners to come under the scrutiny of a suspicious internal affairs agent.',
#   'When four thick-as-thieves friends arrive in Thailand they quickly find themselves in over their heads. Fighting to stay alive they employ their unique set of skills and unleash their fierce loyalty in a heart-pumping battle for survival.',
#   "After a disease kills 98% of America's children, the surviving 2% develop superpowers and are placed in internment camps. A 16-year-old girl escapes her camp and joins a group of other teens on the run from the government.",
#   'After reuniting with Gwen Stacy, Brooklyn’s full-time, friendly neighborhood Spider-Man is catapulted across the Multiverse, where he encounters the Spider Society, a team of Spider-People charged with protecting the Multiverse’s very existence. But when the heroes clash on how to handle a new threat, Miles finds himself pitted against the other Spiders and must set out on his own to save those he loves most.',
#   'With the price on his head ever increasing, John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes
#   'Deep in the wilderness of Lapland, Aatami Korpi is searching for gold but after he stumbles upon Nazi patrol, a breathtaking and gold-hungry chase through the destroyed and mined Lapland wilderness begins.',
#   'When an unknown disease wipes out most of the world’s population, a man with unique blood is isolated for study. Fearing for his wife’s safety, he breaks his quarantine – into a world overrun by monstrous Infected and a shadowy agency hunting them down.',
#   'A knight framed for a tragic crime teams with a scrappy, shape-shifting teen to prove his innocence.',
#   "Finding himself in a new era, approaching retirement, Indy wrestles with fitting into a world that seems to have outgrown him. But as the tentacles of an all-too-familiar evil return in the form of an old rival, Indy must don his hat and pick up his whip once more to make sure an ancient and powerful artifact doesn't fall into the wrong hands.",
#   'Puss in Boots discovers that his passion for adventure has taken its toll: He has burned through eight of his nine lives, leaving him with only one life left. Puss sets out on an epic journey to find the mythical Last Wish and restore his nine lives.',
#   'After dominating the boxing world, Adonis Creed has thrived in his career and family life. When a childhood friend and former boxing prodigy, Damian Anderson, resurfaces after serving a long sentence in prison, he is eager to prove that he deserves his shot in the ring. The face-off between former friends is more than just a fight. To settle the score, Adonis must put his future on the line to battle Damian — a fighter with nothing to lose.',
#   'Billy Batson and his foster siblings, who transform into superheroes by saying "Shazam!", are forced to get back into action and fight the Daughters of Atlas, who they must stop from using a weapon that could destroy the world.',
#   'Unjustly accused of staging a spooky practical joke complete with ghosts, Daphne, Velma, Fred and Shaggy are suspended from Coolsville High. To clear their names, they team up to solve the supernatural mystery…and head straight into nonstop laughs and adventure.'],
#  'popularity': [5935.577,
#   2270.366,
#   2233.242,
#   2759.747,
#   1638.197,
#   1877.321,
#   1213.528,
#   1296.973,
#   1231.388,
#   1244.005,
#   1147.595,
#   1198.255,
#   1139.209,
#   960.045,
#   984.278,
#   909.851,
#   906.387,
#   892.411,
#   917.885,
#   847.514,
#   897.028,
#   693.899,
#   764.705,
#   681.563,
#   653.692,
#   654.856,
#   705.54,
#   617.493,
#   623.518,
#   642.836,
#   608.113,
#   567.982,
#   518.058,
#   529.153,
#   532.88,
#   521.707,
#   547.267,
#   470.945,
#   437.772,
#   454.923,
#   387.535,
#   470.361,
#   472.89,
#   429.21,
#   430.081,
#   380.09,
#   430.732,
#   373.266,
#   364.567,
#   381.424],
#  'poster_path': ['/r2J02Z2OpNTctfOSN1Ydgii51I3.jpg',
#   '/fiVW06jE7z9YnO4trhaMEdclSiC.jpg',
#   '/tBiUXvCqz34GDeuY7jK14QQdtat.jpg',
#   '/gPbM0MK8CP8A174rmUwGsADNYKD.jpg',
#   '/2Gfjn962aaFSD6eST6QU3oLDZTo.jpg',
#   '/mx4O9OEvIB265VM3UATLslsSW5t.jpg',
#   '/qyU7H6OIvojQW0pjgjZjyNCP343.jpg',
#   '/itUAkQmihFmRxMYTa3AkvIzMCV4.jpg',
#   '/94RaS52zmsqaiAe1TG20pdbJCZr.jpg',
#   '/8Vt6mWEReuy4Of61Lnj5Xj704m8.jpg',
#   '/vZloFAK7NmvMGKE7VkF5UHaz0I.jpg',
#   '/nb9fc9INMg8kQ8L7sE7XTNsZnUX.jpg',
#   '/qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg',
#   '/evxtv4e8Amm436Y5rW16RkGu8pX.jpg',
#   '/8riWcADI1ekEiBguVB9vkilhiQm.jpg',
#   '/c3CUKHtQUvPvp9NSFsKwYsPLAdW.jpg',
#   '/7gKI9hpEMcZUQpNgKrkDzJpbnNS.jpg',
#   '/uS1AIL7I1Ycgs8PTfqUeN6jYNsQ.jpg',
#   '/cgYg04miVQUAG2FKk3amSnnHzOp.jpg',
#   '/4VlXER3FImHeFuUjBShFamhIp9M.jpg',
#   '/xbSuFiJbbBWCkyCCKIMfuDCA4yV.jpg',
#   '/9yTuw6ddf28lItHwgeqFSNtXsaG.jpg',
#   '/NNxYkU70HPurnNCSiCjYAmacwm.jpg',
#   '/ablrE8IbWcIrAxMmm4gnPn75AMS.jpg',
#   '/67ZsRKbItt6B1yHlsJKgfPWOyuJ.jpg',
#   '/ym1dxyOk4jFcSl4Q2zmRrA5BEEN.jpg',
#   '/w46Vw536HwNnEzOa7J24YH9DPRS.jpg',
#   '/rktDFPbfHfUbArZ6OOOKsXcv0Bm.jpg',
#   '/t6HIqrRAclMCA60NsSmeqe9RmNV.jpg',
#   '/8qOTi8VXvnuLH0jijMBCyygtV9d.jpg',
#   '/cgetiYyTqJ4CMmPmvDw30nnYj1f.jpg',
#   '/tiZF8b9T9fMcwvsEEkJ5ik1wCnV.jpg',
#   '/3IhGkkalwXguTlceGSl8XUJZOVI.jpg',
#   '/5ik4ATKmNtmJU6AYD0bLm56BCVM.jpg',
#   '/uiFcFIjig0YwyNmhoxkxtAAVIL2.jpg',
#   '/i1a1rk2qPrxIF5pYyBB2oSTa6OR.jpg',
#   '/3LShl6EwqptKIVq6NWOZ0FbZHEe.jpg',
#   '/gNPqcv1tAifbN7PRNgqpzY8sEJZ.jpg',
#   '/sNAeYA5EZ7ouoHnVxQ0vMbfgiEi.jpg',
#   '/kVG8zFFYrpyYLoHChuEeOGAd6Ru.jpg',
#   '/7uJkLigRamfHerFSkfFOCMqH0pi.jpg',
#   '/qnqGbB22YJ7dSs4o6M7exTpNxPz.jpg',
#   '/ygO9lowFMXWymATCrhoQXd6gCEh.jpg',
#   '/6XZYA9VtCcidCU8Hus0J0V9wFhY.jpg',
#   '/2NQljeavtfl22207D1kxLpa4LS3.jpg',
#   '/Af4bXE63pVsb2FtbW8uYIyPBadD.jpg',
#   '/kuf6dutpsT0vSVehic3EZIqkOBt.jpg',
#   '/cvsXj3I9Q2iyyIo95AecSd1tad7.jpg',
#   '/A3ZbZsmsvNGdprRi2lKgGEeVLEH.jpg',
#   '/fUbx2NFwRTmRMtwcTbzEd804WQj.jpg'],
#  'production_companies': [[{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'},
#    {'id': 176762,
#     'logo_path': None,
#     'name': 'Kevin Feige Productions',
#     'origin_country': 'US'}],
#   [{'id': 33,
#     'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'},
#    {'id': 333,
#     'logo_path': '/5xUJfzPZ8jWJUDzYtIeuPO4qPIa.png',
#     'name': 'Original Film',
#     'origin_country': 'US'},
#    {'id': 1225,
#     'logo_path': '/rIxhJMR7oK8b2fMakmTfRLY2TZv.png',
#     'name': 'One Race',
#     'origin_country': 'US'},
#    {'id': 34530,
#     'logo_path': None,
#     'name': 'Perfect Storm Entertainment',
#     'origin_country': 'US'}],
#   [{'id': 11341,
#     'logo_path': '/xytTBODEy3p20ksHL4Ftxr483Iv.png',
#     'name': 'Stage 6 Films',
#     'origin_country': 'US'},
#    {'id': 5542,
#     'logo_path': '/ayE4LIqoAWotavo7xdvYngwqGML.png',
#     'name': 'Toei Animation',
#     'origin_country': 'JP'}],
#   [{'id': 82819,
#     'logo_path': '/gXfFl9pRPaoaq14jybEn1pHeldr.png',
#     'name': 'Skydance',
#     'origin_country': 'US'},
#    {'id': 4,
#     'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png',
#     'name': 'Paramount',
#     'origin_country': 'US'},
#    {'id': 435,
#     'logo_path': '/AjzK0s2w1GtLfR4hqCjVSYi0Sr8.png',
#     'name': 'di Bonaventura Pictures',
#     'origin_country': 'US'},
#    {'id': 6734,
#     'logo_path': None,
#     'name': 'Bay Films',
#     'origin_country': 'US'},
#    {'id': 114732,
#     'logo_path': '/tNCbisMxO5mX2X2bOQxHHQZVYnT.png',
#     'name': 'New Republic Pictures',
#     'origin_country': 'US'},
#    {'id': 38831,
#     'logo_path': None,
#     'name': 'Tom DeSanto/Don Murphy Production',
#     'origin_country': ''},
#    {'id': 2598,
#     'logo_path': '/i42C5gRq7XqlG4S9vkchuJZfrBn.png',
#     'name': 'Hasbro',
#     'origin_country': 'US'}],
#   [{'id': 12,
#     'logo_path': '/5ThIuO93vsk47oexKTSdfKEr7EC.png',
#     'name': 'New Line Cinema',
#     'origin_country': 'US'},
#    {'id': 79,
#     'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#     'name': 'Village Roadshow Pictures',
#     'origin_country': 'US'},
#    {'id': 34081,
#     'logo_path': None,
#     'name': 'Flynn Picture Company',
#     'origin_country': 'US'},
#    {'id': 174,
#     'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#     'name': 'Warner Bros. Pictures',
#     'origin_country': 'US'}],
#   [{'id': 90508,
#     'logo_path': None,
#     'name': 'Santa Fe Films',
#     'origin_country': 'US'}],
#   [{'id': 121204,
#     'logo_path': '/vbtvY4IxgUZk713rkmoTO4MHIac.png',
#     'name': 'BondIt Media Capital',
#     'origin_country': 'US'},
#    {'id': 121063,
#     'logo_path': None,
#     'name': 'Red Sea Media',
#     'origin_country': 'US'},
#    {'id': 130900,
#     'logo_path': None,
#     'name': 'Buffalo 8 Productions',
#     'origin_country': 'US'},
#    {'id': 1632,
#     'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png',
#     'name': 'Lionsgate',
#     'origin_country': 'US'}],
#   [{'id': 121204,
#     'logo_path': '/vbtvY4IxgUZk713rkmoTO4MHIac.png',
#     'name': 'BondIt Media Capital',
#     'origin_country': 'US'},
#    {'id': 41735,
#     'logo_path': '/je9Ko1f6iu0AfLL3dINJEaxLvEb.png',
#     'name': 'Buffalo 8',
#     'origin_country': 'US'},
#    {'id': 139740,
#     'logo_path': None,
#     'name': 'The Squid Farm',
#     'origin_country': ''}],
#   [{'id': 2575,
#     'logo_path': '/9YJrHYlcfHtwtulkFMAies3aFEl.png',
#     'name': '21 Laps Entertainment',
#     'origin_country': 'US'},
#    {'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'}],
#   [{'id': 5,
#     'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#     'name': 'Columbia Pictures',
#     'origin_country': 'US'},
#    {'id': 2251,
#     'logo_path': '/5ilV5mH3gxTEU7p5wjxptHvXkyr.png',
#     'name': 'Sony Pictures Animation',
#     'origin_country': 'US'},
#    {'id': 77973,
#     'logo_path': '/9y5lW86HnxKUZOFencYk3TIIRCM.png',
#     'name': 'Lord Miller',
#     'origin_country': 'US'},
#    {'id': 84041,
#     'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png',
#     'name': 'Pascal Pictures',
#     'origin_country': 'US'},
#    {'id': 14439,
#     'logo_path': None,
#     'name': 'Arad Productions',
#     'origin_country': 'US'}],
#   [{'id': 3528,
#     'logo_path': '/cCzCClIzIh81Fa79hpW5nXoUsHK.png',
#     'name': 'Thunder Road',
#     'origin_country': 'US'},
#    {'id': 23008,
#     'logo_path': '/5SarYupipdiejsEqUkwu1SpYfru.png',
#     'name': '87Eleven',
#     'origin_country': 'US'},
#    {'id': 491,
#     'logo_path': '/5LvDUt3KmvRnXQ4NrdWJYHeuA8J.png',
#     'name': 'Summit Entertainment',
#     'origin_country': 'US'},
#    {'id': 264,
#     'logo_path': '/fA90qwUKgPhMONqtwY60GaHRyrW.png',
#     'name': 'Studio Babelsberg',
#     'origin_country': 'DE'}],
#   [{'id': 11341,
#     'logo_path': '/xytTBODEy3p20ksHL4Ftxr483Iv.png',
#     'name': 'Stage 6 Films',
#     'origin_country': 'US'},
#    {'id': 3172,
#     'logo_path': '/kDedjRZwO8uyFhuHamomOhN6fzG.png',
#     'name': 'Blumhouse Productions',
#     'origin_country': 'US'},
#    {'id': 14734,
#     'logo_path': None,
#     'name': 'Oren Peli Productions',
#     'origin_country': 'US'},
#    {'id': 76907,
#     'logo_path': '/ygMQtjsKX7BZkCQhQZY82lgnCUO.png',
#     'name': 'Atomic Monster',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'}],
#   [{'id': 33,
#     'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'},
#    {'id': 6704,
#     'logo_path': '/fOG2oY4m1YuYTQh4bMqqZkmgOAI.png',
#     'name': 'Illumination',
#     'origin_country': 'US'},
#    {'id': 12288,
#     'logo_path': '/e4dQAqZD374H5EuM0W1ljEBWTKy.png',
#     'name': 'Nintendo',
#     'origin_country': 'JP'}],
#   [{'id': 2735,
#     'logo_path': None,
#     'name': 'Mid Atlantic Films',
#     'origin_country': 'HU'},
#    {'id': 290,
#     'logo_path': '/jrgCuaQsY9ouP5ILZf4Dq4ZOkIX.png',
#     'name': 'Ingenious Media',
#     'origin_country': 'GB'},
#    {'id': 444,
#     'logo_path': None,
#     'name': 'Dune Entertainment',
#     'origin_country': 'US'},
#    {'id': 10893,
#     'logo_path': None,
#     'name': 'Big Screen Productions',
#     'origin_country': ''},
#    {'id': 12292,
#     'logo_path': '/4GQTeqos2luopEtp3OgMQYusQ5c.png',
#     'name': 'Temple Hill Entertainment',
#     'origin_country': 'US'},
#    {'id': 22213,
#     'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png',
#     'name': 'TSG Entertainment',
#     'origin_country': 'US'},
#    {'id': 34396,
#     'logo_path': '/32y3tiWkKJ8uuaB0GaGnvV3AcGa.png',
#     'name': 'Giant Pictures',
#     'origin_country': ''},
#    {'id': 34397,
#     'logo_path': None,
#     'name': 'Origo Film Group',
#     'origin_country': ''},
#    {'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'}],
#   [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 3,
#     'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png',
#     'name': 'Pixar',
#     'origin_country': 'US'}],
#   [{'id': 200553,
#     'logo_path': None,
#     'name': 'Doorbell Productions',
#     'origin_country': ''},
#    {'id': 77781,
#     'logo_path': None,
#     'name': "Lola's Productions",
#     'origin_country': ''},
#    {'id': 200554, 'logo_path': None, 'name': 'Seeon', 'origin_country': ''}],
#   [{'id': 106544,
#     'logo_path': '/psd84iF7PTGrKf4yFOStKj8JbAh.png',
#     'name': 'AGBO',
#     'origin_country': 'US'},
#    {'id': 104576,
#     'logo_path': '/sNhEzePPkxW3AKqr3l0h7I1k0hR.png',
#     'name': 'Filmhaus Films',
#     'origin_country': 'AT'}],
#   [{'id': 3172,
#     'logo_path': '/kDedjRZwO8uyFhuHamomOhN6fzG.png',
#     'name': 'Blumhouse Productions',
#     'origin_country': 'US'},
#    {'id': 11341,
#     'logo_path': '/xytTBODEy3p20ksHL4Ftxr483Iv.png',
#     'name': 'Stage 6 Films',
#     'origin_country': 'US'},
#    {'id': 3287,
#     'logo_path': '/bz6GbCQQXGNE56LTW9dwgksW0Iw.png',
#     'name': 'Screen Gems',
#     'origin_country': 'US'},
#    {'id': 76907,
#     'logo_path': '/ygMQtjsKX7BZkCQhQZY82lgnCUO.png',
#     'name': 'Atomic Monster',
#     'origin_country': 'US'},
#    {'id': 14734,
#     'logo_path': None,
#     'name': 'Oren Peli Productions',
#     'origin_country': 'US'}],
#   [{'id': 82968,
#     'logo_path': '/gRROMOG5bpF6TIDMbfaa5gnFFzl.png',
#     'name': 'LuckyChap Entertainment',
#     'origin_country': 'US'},
#    {'id': 437,
#     'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png',
#     'name': 'Heyday Films',
#     'origin_country': 'GB'},
#    {'id': 168848,
#     'logo_path': '/omEguKifcJixMvKWq85sUp4lFdT.png',
#     'name': 'Mattel Films',
#     'origin_country': 'US'}],
#   [{'id': 2785,
#     'logo_path': '/l5zW8jjmQOCx2dFmvnmbYmqoBmL.png',
#     'name': 'Warner Bros. Animation',
#     'origin_country': 'US'}],
#   [{'id': 12,
#     'logo_path': '/5ThIuO93vsk47oexKTSdfKEr7EC.png',
#     'name': 'New Line Cinema',
#     'origin_country': 'US'},
#    {'id': 11565,
#     'logo_path': None,
#     'name': 'The Safran Company',
#     'origin_country': 'US'},
#    {'id': 76907,
#     'logo_path': '/ygMQtjsKX7BZkCQhQZY82lgnCUO.png',
#     'name': 'Atomic Monster',
#     'origin_country': 'US'}],
#   [{'id': 3361,
#     'logo_path': '/sDKWkiVJRY0gn1j5NBseGKlgFyY.png',
#     'name': 'Digital Frontier',
#     'origin_country': 'JP'},
#    {'id': 882,
#     'logo_path': '/iDw9Xxok1d9WAM2zFicI8p3khTH.png',
#     'name': 'TOHO',
#     'origin_country': 'JP'}],
#   [{'id': 4,
#     'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png',
#     'name': 'Paramount',
#     'origin_country': 'US'},
#    {'id': 82819,
#     'logo_path': '/gXfFl9pRPaoaq14jybEn1pHeldr.png',
#     'name': 'Skydance',
#     'origin_country': 'US'},
#    {'id': 21777,
#     'logo_path': None,
#     'name': 'TC Productions',
#     'origin_country': 'US'}],
#   [{'id': 2785,
#     'logo_path': '/l5zW8jjmQOCx2dFmvnmbYmqoBmL.png',
#     'name': 'Warner Bros. Animation',
#     'origin_country': 'US'}],
#   [{'id': 185718,
#     'logo_path': None,
#     'name': 'Rock Solid Productions',
#     'origin_country': ''},
#    {'id': 4322,
#     'logo_path': '/AkdxBRkqgx0bHjjLvIyl0Mu8sxa.png',
#     'name': 'Compound B',
#     'origin_country': 'US'},
#    {'id': 185719,
#     'logo_path': None,
#     'name': 'White Snake Golden Dragon',
#     'origin_country': ''}],
#   [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 17021,
#     'logo_path': None,
#     'name': 'Lucamar Productions',
#     'origin_country': ''},
#    {'id': 2527,
#     'logo_path': '/osO7TGmlRMistSQ5JZusPhbKUHk.png',
#     'name': 'Marc Platt Productions',
#     'origin_country': 'US'}],
#   [{'id': 32485,
#     'logo_path': '/fVXreZkiJTOq1cCi6htSQlPSy7R.png',
#     'name': 'Pokeepsie Films',
#     'origin_country': 'ES'},
#    {'id': 20580,
#     'logo_path': '/oRR9EXVoKP9szDkVKlze5HVJS7g.png',
#     'name': 'Amazon Studios',
#     'origin_country': 'US'}],
#   [{'id': 174,
#     'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#     'name': 'Warner Bros. Pictures',
#     'origin_country': 'US'},
#    {'id': 152809,
#     'logo_path': None,
#     'name': 'Double Dream',
#     'origin_country': 'US'},
#    {'id': 170335,
#     'logo_path': None,
#     'name': 'The Disco Factory',
#     'origin_country': 'US'},
#    {'id': 128064,
#     'logo_path': '/13F3Jf7EFAcREU0xzZqJnVnyGXu.png',
#     'name': 'DC Films',
#     'origin_country': 'US'}],
#   [{'id': 127928,
#     'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#     'name': '20th Century Studios',
#     'origin_country': 'US'},
#    {'id': 574,
#     'logo_path': '/iB6GjNVHs5hOqcEYt2rcjBqIjki.png',
#     'name': 'Lightstorm Entertainment',
#     'origin_country': 'US'}],
#   [{'id': 181859,
#     'logo_path': None,
#     'name': 'ERO Picture Company',
#     'origin_country': 'CA'}],
#   [{'id': 71767,
#     'logo_path': None,
#     'name': 'Carver Films',
#     'origin_country': 'AU'},
#    {'id': 12142,
#     'logo_path': '/rPnEeMwxjI6rYMGqkWqIWwIJXxi.png',
#     'name': 'XYZ Films',
#     'origin_country': 'US'}],
#   [{'id': 47729,
#     'logo_path': '/5NRpQ7xxmODXAjt2pRWUFMLVzvP.png',
#     'name': 'STX Films',
#     'origin_country': 'US'},
#    {'id': 130448,
#     'logo_path': '/yHWTTGKbOGZKUd1cp6l3uLyDeiv.png',
#     'name': 'Project X Entertainment',
#     'origin_country': 'US'},
#    {'id': 121204,
#     'logo_path': '/vbtvY4IxgUZk713rkmoTO4MHIac.png',
#     'name': 'BondIt Media Capital',
#     'origin_country': 'US'}],
#   [{'id': 77863,
#     'logo_path': '/7z6YOzvdk70YY8OaRbn5mfxrvbO.png',
#     'name': 'Studio 8',
#     'origin_country': 'US'},
#    {'id': 52180,
#     'logo_path': None,
#     'name': 'Solstice Productions',
#     'origin_country': 'US'},
#    {'id': 290,
#     'logo_path': '/jrgCuaQsY9ouP5ILZf4Dq4ZOkIX.png',
#     'name': 'Ingenious Media',
#     'origin_country': 'GB'},
#    {'id': 158413,
#     'logo_path': None,
#     'name': 'Double R Productions',
#     'origin_country': 'US'}],
#   [{'id': 12,
#     'logo_path': '/5ThIuO93vsk47oexKTSdfKEr7EC.png',
#     'name': 'New Line Cinema',
#     'origin_country': 'US'},
#    {'id': 768,
#     'logo_path': None,
#     'name': 'Ghost House Pictures',
#     'origin_country': 'US'},
#    {'id': 467,
#     'logo_path': None,
#     'name': 'Renaissance Pictures',
#     'origin_country': 'US'},
#    {'id': 7893,
#     'logo_path': None,
#     'name': 'Pacific Renaissance Pictures',
#     'origin_country': 'NZ'},
#    {'id': 129815,
#     'logo_path': '/qbCmnVTQEuFqrVkbxn3i9P7Jrcw.png',
#     'name': 'Wild Atlantic Pictures',
#     'origin_country': 'IE'}],
#   [{'id': 78193,
#     'logo_path': '/4fFGVQ0XYnkb9n0CbH6xc0aHtBM.png',
#     'name': 'Mucho Mas Media',
#     'origin_country': 'US'},
#    {'id': 151485,
#     'logo_path': '/8WMlxjc69DhHc8D5wbEN4mkU9rY.png',
#     'name': 'Silk Mass',
#     'origin_country': 'US'},
#    {'id': 185127,
#     'logo_path': '/lD5UjvX5MsbIwbZJvdC5aee1nwm.png',
#     'name': 'The Avenue Entertainment',
#     'origin_country': 'US'},
#    {'id': 76991,
#     'logo_path': '/pQjdvbv4y9yuIDSHDEHc9ijJKaS.png',
#     'name': 'Highland Film Group',
#     'origin_country': 'US'}],
#   [{'id': 20064,
#     'logo_path': '/2In7Heq6DuXDjOwPmJqHWkpohaL.png',
#     'name': 'Next Entertainment World',
#     'origin_country': 'KR'},
#    {'id': 85150,
#     'logo_path': '/dXGvoNR0ni359HmKefOAIMY7WcE.png',
#     'name': 'Zip Cinema',
#     'origin_country': 'KR'},
#    {'id': 7270,
#     'logo_path': None,
#     'name': 'Opus Pictures',
#     'origin_country': 'KR'},
#    {'id': 88607,
#     'logo_path': None,
#     'name': 'Union Investment Partners',
#     'origin_country': 'KR'},
#    {'id': 3394,
#     'logo_path': None,
#     'name': 'Sundream Motion Pictures',
#     'origin_country': 'HK'},
#    {'id': 100305,
#     'logo_path': '/aVyp89twN22GhC2sZTkRP9gHHeX.png',
#     'name': 'Seoul Film Commission',
#     'origin_country': 'KR'},
#    {'id': 197889,
#     'logo_path': None,
#     'name': 'United Pictures',
#     'origin_country': 'KR'},
#    {'id': 7036,
#     'logo_path': '/javbyY0ZCvlFJtly3tpZqf2NwLX.png',
#     'name': 'CJ Entertainment',
#     'origin_country': 'KR'}],
#   [{'id': 150179,
#     'logo_path': None,
#     'name': 'Post Film',
#     'origin_country': ''},
#    {'id': 18609,
#     'logo_path': '/cYhbt3q231mWEkiMn3WPLCcXXl9.png',
#     'name': 'BoulderLight Pictures',
# ...
#      'credit_id': '64a44d928e20c500cbecdf27',
#      'department': 'Art',
#      'job': 'Construction Foreman'},
#     {'adult': False,
#      'gender': 2,
#      'id': 1462843,
#      'known_for_department': 'Sound',
#      'name': 'Sean Madsen',
#      'original_name': 'Sean Madsen',
#      'popularity': 1.96,
#      'profile_path': None,
#      'credit_id': '64a456328c44b9012d6b6dac',
#      'department': 'Sound',
#      'job': 'Assistant Sound Editor'},
#     {'adult': False,
#      'gender': 2,
#      'id': 1463123,
#      'known_for_department': 'Sound',
#      'name': 'Ben Whitver',
#      'original_name': 'Ben Whitver',
#      'popularity': 1.38,
#      'profile_path': None,
#      'credit_id': '64a455fda0be2800ecfcb9c6',
#      'department': 'Sound',
#      'job': 'ADR Mixer'},
#     {'adult': False,
#      'gender': 2,
#      'id': 1536923,
#      'known_for_department': 'Editing',
#      'name': 'Eric Osmond',
#      'original_name': 'Eric Osmond',
#      'popularity': 2.557,
#      'profile_path': None,
#      'credit_id': '5a7c09b8c3a3680f7f00aae8',
#      'department': 'Editing',
#      'job': 'Editor'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1541457,
#      'known_for_department': 'Editing',
#      'name': 'Travis Dultz',
#      'original_name': 'Travis Dultz',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a452ec8289a0014e75cec5',
#      'department': 'Editing',
#      'job': 'First Assistant Editor'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1552473,
#      'known_for_department': 'Camera',
#      'name': 'Kieran Humphries',
#      'original_name': 'Kieran Humphries',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44a5f8289a000ae8971c1',
#      'department': 'Camera',
#      'job': 'First Assistant "A" Camera'},
#     {'adult': False,
#      'gender': 2,
#      'id': 1556488,
#      'known_for_department': 'Visual Effects',
#      'name': 'Peter V. Ware',
#      'original_name': 'Peter V. Ware',
#      'popularity': 0.98,
#      'profile_path': None,
#      'credit_id': '64a436c6e9da6900ae2fc48b',
#      'department': 'Visual Effects',
#      'job': 'Visual Effects Producer'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1577957,
#      'known_for_department': 'Visual Effects',
#      'name': 'James Kozier',
#      'original_name': 'James Kozier',
#      'popularity': 0.664,
#      'profile_path': None,
#      'credit_id': '64a44e03e8d02800ff8b6165',
#      'department': 'Crew',
#      'job': 'Special Effects'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1653534,
#      'known_for_department': 'Lighting',
#      'name': 'Rory Soderman',
#      'original_name': 'Rory Soderman',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44c99e9da6900ae2fce8e',
#      'department': 'Lighting',
#      'job': 'Assistant Chief Lighting Technician'},
#     {'adult': False,
#      'gender': 2,
#      'id': 1698264,
#      'known_for_department': 'Crew',
#      'name': 'Jan Kikumoto',
#      'original_name': 'Jan Kikumoto',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44ec211386c011c3b7624',
#      'department': 'Crew',
#      'job': 'Post Production Supervisor'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1762832,
#      'known_for_department': 'Crew',
#      'name': 'Steve Woodley',
#      'original_name': 'Steve Woodley',
#      'popularity': 1.03,
#      'profile_path': None,
#      'credit_id': '64a44e41e8d02800ac076422',
#      'department': 'Crew',
#      'job': 'Animal Wrangler'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1804884,
#      'known_for_department': 'Camera',
#      'name': 'John Kuchera',
#      'original_name': 'John Kuchera',
#      'popularity': 0.695,
#      'profile_path': None,
#      'credit_id': '64a44cbde8d028011cf9a4b5',
#      'department': 'Camera',
#      'job': 'Key Grip'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1819582,
#      'known_for_department': 'Directing',
#      'name': 'Karin Behrenz',
#      'original_name': 'Karin Behrenz',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44b478289a0010ced5ab8',
#      'department': 'Directing',
#      'job': 'Third Assistant Director'},
#     {'adult': False,
#      'gender': 1,
#      'id': 1868976,
#      'known_for_department': 'Production',
#      'name': 'Michele MacInnes',
#      'original_name': 'Michele MacInnes',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44b08e9da69011e587c24',
#      'department': 'Production',
#      'job': 'Production Office Coordinator'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1889656,
#      'known_for_department': 'Production',
#      'name': 'Melyssa Rose',
#      'original_name': 'Melyssa Rose',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44b308289a0014e75cb08',
#      'department': 'Production',
#      'job': 'Assistant Production Coordinator'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1904982,
#      'known_for_department': 'Costume & Make-Up',
#      'name': 'April Boyes',
#      'original_name': 'April Boyes',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44c108e20c5010d4ede29',
#      'department': 'Costume & Make-Up',
#      'job': 'Key Makeup Artist'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1904994,
#      'known_for_department': 'Camera',
#      'name': 'Stephen J. McKnight',
#      'original_name': 'Stephen J. McKnight',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44a99e9da6900ae2fcd76',
#      'department': 'Camera',
#      'job': 'First Assistant "B" Camera'},
#     {'adult': False,
#      'gender': 2,
#      'id': 1946100,
#      'known_for_department': 'Camera',
#      'name': 'Paul Arnel',
#      'original_name': 'Paul Arnel',
#      'popularity': 0.694,
#      'profile_path': None,
#      'credit_id': '64a44ccc8289a0012d29767f',
#      'department': 'Camera',
#      'job': 'Best Boy Grip'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1963227,
#      'known_for_department': 'Camera',
#      'name': 'David Kershaw',
#      'original_name': 'David Kershaw',
#      'popularity': 0.828,
#      'profile_path': None,
#      'credit_id': '64a44cdfe8d028013916d3b7',
#      'department': 'Camera',
#      'job': 'Dolly Grip'},
#     {'adult': False,
#      'gender': 0,
#      'id': 1972625,
#      'known_for_department': 'Costume & Make-Up',
#      'name': 'Moira Fentum',
#      'original_name': 'Moira Fentum',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44bfbd400f300caacd921',
#      'department': 'Costume & Make-Up',
#      'job': 'Costumer'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2022179,
#      'known_for_department': 'Art',
#      'name': 'Laura Schneider',
#      'original_name': 'Laura Schneider',
#      'popularity': 0.694,
#      'profile_path': None,
#      'credit_id': '64a44d618e20c5014f2b270e',
#      'department': 'Art',
#      'job': 'Assistant Property Master'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2038205,
#      'known_for_department': 'Production',
#      'name': 'Ken Brooker',
#      'original_name': 'Ken Brooker',
#      'popularity': 0.694,
#      'profile_path': None,
#      'credit_id': '64a44b8c8289a000caf1b344',
#      'department': 'Production',
#      'job': 'Location Manager'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2056802,
#      'known_for_department': 'Sound',
#      'name': 'Roderick Matte',
#      'original_name': 'Roderick Matte',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44ae38289a000caf1b307',
#      'department': 'Sound',
#      'job': 'Boom Operator'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2061305,
#      'known_for_department': 'Sound',
#      'name': 'Doug Latislaw',
#      'original_name': 'Doug Latislaw',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a455ee5a991500e3c7c172',
#      'department': 'Sound',
#      'job': 'ADR Mixer'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2067374,
#      'known_for_department': 'Art',
#      'name': 'D. Martin Myatt',
#      'original_name': 'D. Martin Myatt',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44d73d400f300ebff987e',
#      'department': 'Art',
#      'job': 'Props'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2080234,
#      'known_for_department': 'Crew',
#      'name': 'Ron Kozier',
#      'original_name': 'Ron Kozier',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44e16e8d02800ff8b616f',
#      'department': 'Crew',
#      'job': 'Special Effects'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2108678,
#      'known_for_department': 'Production',
#      'name': 'Karen Pelrine',
#      'original_name': 'Karen Pelrine',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44b1e11386c00e2160cc4',
#      'department': 'Production',
#      'job': 'Assistant Production Coordinator'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2127289,
#      'known_for_department': 'Crew',
#      'name': 'Eric Lemay',
#      'original_name': 'Eric Lemay',
#      'popularity': 1.164,
#      'profile_path': None,
#      'credit_id': '64a44df1e9da69013b7892c7',
#      'department': 'Crew',
#      'job': 'Special Effects Coordinator'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2142550,
#      'known_for_department': 'Camera',
#      'name': 'Adriene Wyse',
#      'original_name': 'Adriene Wyse',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44aa811386c0139af1e46',
#      'department': 'Camera',
#      'job': 'Second Assistant "B" Camera'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2157833,
#      'known_for_department': 'Camera',
#      'name': 'Carrie Wilson',
#      'original_name': 'Carrie Wilson',
#      'popularity': 0.607,
#      'profile_path': None,
#      'credit_id': '64a44a7511386c00adc879f3',
#      'department': 'Camera',
#      'job': 'Second Assistant "A" Camera'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2328302,
#      'known_for_department': 'Crew',
#      'name': 'Darcy Woodley',
#      'original_name': 'Darcy Woodley',
#      'popularity': 0.98,
#      'profile_path': None,
#      'credit_id': '64a44e34d400f3012d449e20',
#      'department': 'Crew',
#      'job': 'Animal Wrangler'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2349293,
#      'known_for_department': 'Costume & Make-Up',
#      'name': 'Allison Chretien',
#      'original_name': 'Allison Chretien',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44bea11386c011c3b74d0',
#      'department': 'Costume & Make-Up',
#      'job': 'Costumer'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2476949,
#      'known_for_department': 'Directing',
#      'name': 'Josy Capkun',
#      'original_name': 'Josy Capkun',
#      'popularity': 0.925,
#      'profile_path': None,
#      'credit_id': '64a44a04e8d02800e2d858f2',
#      'department': 'Directing',
#      'job': 'Second Assistant Director'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2499737,
#      'known_for_department': 'Visual Effects',
#      'name': 'Park Min-su',
#      'original_name': 'Park Min-su',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a4534ce8d02800c5475f7b',
#      'department': 'Visual Effects',
#      'job': 'Visual Effects Supervisor'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2941910,
#      'known_for_department': 'Art',
#      'name': 'David Manske',
#      'original_name': 'David Manske',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44dcbd400f300caacd9ff',
#      'department': 'Art',
#      'job': 'Set Dresser'},
#     {'adult': False,
#      'gender': 1,
#      'id': 2954656,
#      'known_for_department': 'Costume & Make-Up',
#      'name': 'Paulette Nelson',
#      'original_name': 'Paulette Nelson',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44bd9e9da6900e40c51aa',
#      'department': 'Costume & Make-Up',
#      'job': 'Assistant Costume Designer'},
#     {'adult': False,
#      'gender': 1,
#      'id': 2960010,
#      'known_for_department': 'Camera',
#      'name': 'Sylvia Pranaitis',
#      'original_name': 'Sylvia Pranaitis',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44cfc8289a000ebe4d53d',
#      'department': 'Camera',
#      'job': 'Dolly Grip'},
#     {'adult': False,
#      'gender': 0,
#      'id': 2999561,
#      'known_for_department': 'Sound',
#      'name': 'Ian Tarasoff',
#      'original_name': 'Ian Tarasoff',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44af3d400f300caacd89d',
#      'department': 'Sound',
#      'job': 'Utility Sound'},
#     {'adult': False,
#      'gender': 0,
#      'id': 3052668,
#      'known_for_department': 'Sound',
#      'name': 'Zac Anderson',
#      'original_name': 'Zac Anderson',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a4564e5a991500adf7b662',
#      'department': 'Sound',
#      'job': 'Foley Editor'},
#     {'adult': False,
#      'gender': 0,
#      'id': 3052672,
#      'known_for_department': 'Sound',
#      'name': 'Kyle Tilbury',
#      'original_name': 'Kyle Tilbury',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a456201bf26601431b3c54',
#      'department': 'Sound',
#      'job': 'Assistant Sound Editor'},
#     {'adult': False,
#      'gender': 1,
#      'id': 3153174,
#      'known_for_department': 'Editing',
#      'name': 'Sue Gates',
#      'original_name': 'Sue Gates',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a4568d1bf2660105177d42',
#      'department': 'Editing',
#      'job': 'Colorist'},
#     {'adult': False,
#      'gender': 0,
#      'id': 3397532,
#      'known_for_department': 'Crew',
#      'name': 'Sean P. Aislabie',
#      'original_name': 'Sean P. Aislabie',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44ea5e8d028013916d477',
#      'department': 'Crew',
#      'job': 'Craft Service'},
#     {'adult': False,
#      'gender': 0,
#      'id': 3559665,
#      'known_for_department': 'Production',
#      'name': 'Paul Russell',
#      'original_name': 'Paul Russell',
#      'popularity': 0.828,
#      'profile_path': None,
#      'credit_id': '64a44bb58289a0012d297604',
#      'department': 'Production',
#      'job': 'Assistant Location Manager'},
#     {'adult': False,
#      'gender': 0,
#      'id': 3886921,
#      'known_for_department': 'Production',
#      'name': 'Natasha Tony',
#      'original_name': 'Natasha Tony',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44e72e8d02800e2d85ad1',
#      'department': 'Production',
#      'job': 'Extras Casting'},
#     {'adult': False,
#      'gender': 0,
#      'id': 4146855,
#      'known_for_department': 'Sound',
#      'name': 'Lars Ekstrom',
#      'original_name': 'Lars Ekstrom',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44ad5e8d028011cf9a3d8',
#      'department': 'Sound',
#      'job': 'Sound Mixer'},
#     {'adult': False,
#      'gender': 0,
#      'id': 4146864,
#      'known_for_department': 'Production',
#      'name': 'Jane Mason',
#      'original_name': 'Jane Mason',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44b73e9da6900c7640897',
#      'department': 'Production',
#      'job': 'Production Accountant'},
#     {'adult': False,
#      'gender': 0,
#      'id': 4146875,
#      'known_for_department': 'Art',
#      'name': 'Roger Busque',
#      'original_name': 'Roger Busque',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44da0e9da6900ae2fcf15',
#      'department': 'Art',
#      'job': 'Construction Foreman'},
#     {'adult': False,
#      'gender': 0,
#      'id': 4146880,
#      'known_for_department': 'Crew',
#      'name': 'Dave Byerley',
#      'original_name': 'Dave Byerley',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a44e95e8d02800e2d85af1',
#      'department': 'Crew',
#      'job': 'Transportation Captain'},
#     {'adult': False,
#      'gender': 0,
#      'id': 4146946,
#      'known_for_department': 'Sound',
#      'name': 'Caleb Easter',
#      'original_name': 'Caleb Easter',
#      'popularity': 0.6,
#      'profile_path': None,
#      'credit_id': '64a4563fa0be2800cbf5be27',
#      'department': 'Sound',
#      'job': 'Foley Editor'}]}]}

# %%
def dataconversion():
    temp_df['belongs_to_collection'] = temp_df['belongs_to_collection'].apply(lambda x: extractValues(x,'name'))
    temp_df['genres'] = temp_df['genres'].apply(lambda x: extractValues(x,'name'))
    temp_df['production_companies'] = temp_df['production_companies'].apply(lambda x: extractValues(x,'name'))
    temp_df['production_countries'] = temp_df['production_countries'].apply(lambda x: extractValues(x,'name'))
    temp_df['spoken_languages'] = temp_df['spoken_languages'].apply(lambda x: extractValues(x,'name'))
    temp_df['cast'] = temp_df['credits'].apply(lambda x: extractSubValues(x,'cast'))
    temp_df['director'] = temp_df['credits'].apply(lambda x: extractSubValuesCondition(x,'crew','Director'))

# %%
temp_df = pd.DataFrame(temp_dict)
dataconversion()

# %%
temp_df
# Out:
#     adult                     backdrop_path  \
# 0   False  /5YZbUmjbMa3ClvSW1Wj3D6XGolb.jpg
# 1   False  /4XM8DUTQb3lhLemJC51Jx4a2EuA.jp
  /jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg
# 47  False  /8QsVX5C82mT7bB5sVsjsLcerWQK.jpg
# 48  False  /zRQITMLvVi8z2Xz12Bi6wvbZE82.jpg
# 49  False  /tgH4bAlDJjhxies1AuKZkNP5SSI.jpg
#
#                           belongs_to_collection     budget  \
# 0            Guardians of the Galaxy Collection  250000000
# 1           The Fast and the Furious Collection  340000000
# 2                                          None   60000000
# 3   Transformers: Rise of the Beasts Collection  200000000
# 4                                          None  110000000
# 5                                          None          0
# 6                                          None          0
# 7                                          None          0
# 8                                          None   34000000
# 9           Spider-Man: Spider-Verse Collection  100000000
# 10                         John Wick Collection   90000000
# 11                         Insidious Collection   10000000
# 12                                         None  100000000
# 13                          Die Hard Collection   92000000
# 14                                         None  200000000
# 15                                         None          0
# 16                        Extraction Collection          0
# 17                         Insidious Collection   16000000
# 18                                         None  100000000
# 19             Mortal Kombat Legends Collection          0
# 20                     The Conjuring Collection   39000000
# 21                             Gantz Collection          0
# 22               Mission: Impossible Collection  290000000
# 23             Mortal Kombat Legends Collection          0
# 24                                         None          0
# 25                                         None  250000000
# 26                                         None          0
# 27                                         None  190000000
# 28                            Avatar Collection  460000000
# 29                                         None      15000
# 30                                         None          0
# 31                                         None          0
# 32                                         None   70000000
# 33                                         None   15000000
# 34                                         None          0
# 35                                         None          0
# 36                             Becky Collection          0
# 37                                         None   18000000
# 38                                         None          0
# 39                                         None   55000000
# 40                                         None          0
# 41                           Ant-Man Collection  200000000
# 42                                         None    6200000
# 43                                         None       5000
# 44                                         None          0
# 45                     Indiana Jones Collection  295000000
# 46                     Puss in Boots Collection   90000000
# 47                             Creed Collection   75000000
# 48                           Shazam! Collection  125000000
# 49    Scooby-Doo! The Mystery Begins Collection          0
#
#                                            genres  \
# 0              Science Fiction, Adventure, Action
# 1                         Action, Crime, Thriller
# 2                      Fantasy, Action, Adventure
# 3              Action, Adventure, Science Fiction
# 4                         Action, Drama, Thriller
# 5                                   Action, Drama
# 6                       Mystery, Thriller, Action
# 7                           Action, Comedy, Crime
# 8                        Action, Adventure, Drama
# 9   Action, Adventure, Animation, Science Fiction
# 10                        Action, Thriller, Crime
# 11                      Horror, Mystery, Thriller
# 12  Animation, Family, Adventure, Fantasy, Comedy
# 13                               Action, Thriller
# 14    Animation, Comedy, Family, Fantasy, Romance
# 15             Science Fiction, Mystery, Thriller
# 16                               Action, Thriller
# 17                      Horror, Mystery, Thriller
# 18                     Comedy, Adventure, Fantasy
# 19                     Animation, Action, Fantasy
# 20                      Horror, Mystery, Thriller
# 21             Science Fiction, Action, Animation
# 22                    Action, Adventure, Thriller
# 23                     Animation, Action, Fantasy
# 24                      Action, Fantasy, Thriller
# 25            Adventure, Family, Fantasy, Romance
# 26                                 Romance, Drama
# 27             Science Fiction, Action, Adventure
# 28             Science Fiction, Adventure, Action
# 29                                         Horror
# 30                               Horror, Thriller
# 31                                         Horror
# 32             Mystery, Thriller, Science Fiction
# 33                               Thriller, Horror
# 18                                            English  Released
# 19                                            English  Released
# 20                                 English, Português  Released
# 21                                                日本語  Released
# 22               English, Français, Italiano, Pусский  Released
# 23                                            English  Released
# 24                                            English  Released
# 25                                            English  Released
# 26                                            Español  Released
# 27                          English, Pусский, Español  Released
# 28                                            English  Released
# 29                                            English  Released
# 30                                            English  Released
# 31                                            English  Released
# 32                                            English  Released
# 33                                            English  Released
# 34                                   English, Español  Released
# 35                                            한국어/조선말  Released
# 36                                            English  Released
# 37  Italiano, Español, Deutsch, Fulfulde, Latin, E...  Released
# 38                                          广州话 / 廣州話  Released
# 39                         العربية, English, Italiano  Released
# 40                      Afrikaans, isiZulu, , English  Released
# 41                                            English  Released
# 42                                     English, suomi  Released
# 43                                            English  Released
# 44                                            English  Released
# 45  العربية, English, Deutsch, हिन्दी, Italiano, L...  Released
# 46                                   English, Español  Released
# 47                                   English, Español  Released
# 48                                            English  Released
# 49                                            English  Released
#
#                                               tagline  \
# 0                             Once more with feeling.
# 1                         The end of the road begins.
# 2                             Go beyond your destiny.
# 3                                      Unite or fall.
# 4   A rescue pilot survived an earthquake, this is...
# 5          Fight for the light. Silence the darkness.
# 6   The action-thriller movie is based on true events
# 7
# 8         The ones who changed will change everything
# 9             It's how you wear the mask that matters
# 10                          No way back, one way out.
# 11                                   Fear comes home.
# 12
# 13                        Yippee Ki-Yay Mother Russia
# 14                                   Opposites react.
# 15                                     They are here.
# 16                 Prepare for the ride of your life.
# 17                        It ends where it all began.
# 18                   She's everything. He's just Ken.
# 19  Extreme violence. Bad language. And a bloody g...
# 20             The demonic case that shocked America.
# 21
# 22                        We all share the same fate.
# 23
# 24                    From the darkness he will rise.
# 25  Watch and you'll see, some day I'll be, part o...
# 26
# 27                                    Worlds collide.
# 28                                 Return to Pandora.
# 29                                   In this house...
# 30
# 31                                   Fear never rests
# 32                            Control is an illusion.
# 33                          Mommy loves you to death.
# 34                                 Nature bites back.
# 35  Remember everything about the untraceable target.
# 36      Hell hath no fury like a 16-year-old scorned.
# 37  Inspired by the actual files of Father Gabriel...
# 38                There is no chosen sleuth among us.
# 39                    A bond. A pledge. A commitment.
# 40
# 41            Witness the beginning of a new dynasty.
# 42                               Vengeance is golden.
# 43                         Stay Isolated. Stay Alive.
# 44                            A new hero takes shape.
# 45                    A legend will face his destiny.
# 46                    Say hola to his little friends.
# 47                      You can't run from your past.
# 48                                      Oh. My. Gods.
# 49          The greatest mystery is how it all began.
#
#                                             title  video vote_average  \
# 0                  Guardians of the Galaxy Vol. 3  False        8.160
# 1                                          Fast X  False        7.365
# 2                           Knights of the Zodiac  False        6.499
# 3                Transformers: Rise of the Beasts  False        7.280
# 4                                     San Andreas  False        6.213
# 5                                Sound of Freedom  False        8.189
# 6                          Confidential Informant  False        6.400
# 7                                         Sheroes  False        5.000
# 8                               The Darkest Minds  False        7.027
# 9             Spider-Man: Across the Spider-Verse  False        8.512
# 10                           John Wick: Chapter 4  False        7.860
# 11                        Insidious: The Last Key  False        6.255
# 40  S'Dumo Mtshali, Presley Chweneyagae, Brenda Ng...          Donovan Marsh
# 41  Paul Rudd, Evangeline Lilly, Jonathan Majors, ...            Peyton Reed
# 42  Jorma Tommila, Aksel Hennie, Jack Doolan, Mimo...       Jalmari Helander
# 43  Anita Abdinezhad, Christian Masters, Harry Asp...           Daniel Byers
# 44  Chloë Grace Moretz, Riz Ahmed, Eugene Lee Yang...             Troy Quane
# 45  Harrison Ford, Phoebe Waller-Bridge, Antonio B...          James Mangold
# 46  Antonio Banderas, Salma Hayek Pinault, Harvey ...          Joel Crawford
# 47  Michael B. Jordan, Tessa Thompson, Jonathan Ma...      Michael B. Jordan
# 48  Zachary Levi, Asher Angel, Jack Dylan Grazer, ...      David F. Sandberg
# 49  Nick Palatas, Hayley Kiyoko, Frank Welker, Rob...           Brian Levant
#
# [50 rows x 28 columns]

# %%
temp_df.head(2)
# Out:
#    adult                     backdrop_path  \
# 0  False  /5YZbUmjbMa3ClvSW1Wj3D6XGolb.jpg
# 1  False  /4XM8DUTQb3lhLemJC51Jx4a2EuA.jpg
#
#                  belongs_to_collection     budget  \
# 0   Guardians of the Galaxy Collection  250000000
# 1  The Fast and the Furious Collection  340000000
#
#                                genres  \
# 0  Science Fiction, Adventure, Action
# 1             Action, Crime, Thriller
#
#                                             homepage      id    imdb_id  \
# 0  https://www.marvel.com/movies/guardians-of-the...  447365  tt6791350
# 1                             https://fastxmovie.com  385687  tt5433140
#
#   original_language                  original_title  ...  \
# 0                en  Guardians of the Galaxy Vol. 3  ...
# 1                en                          Fast X  ...
#
#                                     spoken_languages    status  \
# 0                                            English  Released
# 1  Español, Bahasa indonesia, English, Italiano, ...  Released
#
#                        tagline                           title  video  \
# 0      Once more with feeling.  Guardians of the Galaxy Vol. 3  False
# 1  The end of the road begins.                          Fast X  False
#
#   vote_average  vote_count                                            credits  \
# 0        8.160        2846  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 1        7.365        2624  {'cast': [{'adult': False, 'gender': 2, 'id': ...
#
#                                                 cast         director
# 0  Chris Pratt, Zoe Saldaña, Dave Bautista, Karen...       James Gunn
# 1  Vin Diesel, Michelle Rodriguez, Tyrese Gibson,...  Louis Leterrier
#
# [2 rows x 28 columns]

# %%
try:
    movies_df = pd.read_csv('./data/movies.csv')
    movies = pd.concat([movies_df,temp_df],axis=0)
    os.remove("./data/movies.csv")
    movies.to_csv('./data/movies.csv')
except:
    #print("Error")
    temp_df.to_csv('./data/movies.csv')

# %% [markdown]
# # Check DF

# %%
check_df = pd.read_csv('./data/movies.csv')

# %%
check_df.id.duplicated().sum()
# Out:
# 0

# %%
wanted_cols = ['adult','backdrop_path','belongs_to_collection','budget','genres','homepage','id','imdb_id','original_language',
               'original_title','overview','popularity','poster_path','production_companies','production_countries',
               'release_date','revenue','runtime','spoken_languages','status','tagline','title','video','vote_average',
               'vote_count','credits','cast','director']

# %%
check_df = check_df[wanted_cols]

# %%
os.remove("./data/movies.csv")
check_df.to_csv('./data/movies.csv')
